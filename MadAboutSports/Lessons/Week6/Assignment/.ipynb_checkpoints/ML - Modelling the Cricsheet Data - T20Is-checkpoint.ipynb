# %%
import pandas as pd
import glob

# %%
d1 = pd.read_csv('../../Datasets/t20i_csv/211028.csv')
d2 = pd.read_csv('../../Datasets/t20i_csv/287864.csv')

# %%
d1.head()
# Out:
#    match_id  season  start_date          venue  innings  ball batting_team  \
# 0    211028    2005  2005-06-13  The Rose Bowl        1   0.1      England
# 1    211028    2005  2005-06-13  The Rose Bowl        1   0.2      England
# 2    211028    2005  2005-06-13  The Rose Bowl        1   0.3      England
# 3    211028    2005  2005-06-13  The Rose Bowl        1   0.4      England
# 4    211028    2005  2005-06-13  The Rose Bowl        1   0.5      England
#
#   bowling_team         striker     non_striker  ... extras  wides  noballs  \
# 0    Australia  ME Trescothick        GO Jones  ...      0    NaN      NaN
# 1    Australia  ME Trescothick        GO Jones  ...      0    NaN      NaN
# 2    Australia        GO Jones  ME Trescothick  ...      0    NaN      NaN
# 3    Australia        GO Jones  ME Trescothick  ...      0    NaN      NaN
# 4    Australia        GO Jones  ME Trescothick  ...      0    NaN      NaN
#
# ...

# %%
d2.head()
# Out:
#    match_id   season  start_date     venue  innings  ball batting_team  \
# 0    287864  2007/08  2007-09-15  Newlands        1   0.1   Bangladesh
# 1    287864  2007/08  2007-09-15  Newlands        1   0.2   Bangladesh
# 2    287864  2007/08  2007-09-15  Newlands        1   0.3   Bangladesh
# 3    287864  2007/08  2007-09-15  Newlands        1   0.4   Bangladesh
# 4    287864  2007/08  2007-09-15  Newlands        1   0.5   Bangladesh
#
#    bowling_team      striker non_striker  ... extras  wides  noballs  byes  \
# 0  South Africa  Tamim Iqbal  Nazimuddin  ...      0    NaN      NaN   NaN
# 1  South Africa  Tamim Iqbal  Nazimuddin  ...      0    NaN      NaN   NaN
# 2  South Africa  Tamim Iqbal  Nazimuddin  ...      0    NaN      NaN   NaN
# 3  South Africa  Tamim Iqbal  Nazimuddin  ...      0    NaN      NaN   NaN
# 4  South Africa  Tamim Iqbal  Nazimuddin  ...      0    NaN      NaN   NaN
#
#    legbyes  penalty  wicket_type  player_dismissed other_wicket_type  \
# ...

# %%
d1.columns == d2.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
allT20i_csvs = glob.glob('../../Datasets/t20i_csv/*.csv')

# %%
print(allT20i_csvs)
# Out:
# ['../../Datasets/t20i_csv/1217744.csv', '../../Datasets/t20i_csv/1268190.csv', '../../Datasets/t20i_csv/1257406.csv', '../../Datasets/t20i_csv/1336952.csv', '../../Datasets/t20i_csv/930579.csv', '../../Datasets/t20i_csv/1142919.csv', '../../Datasets/t20i_csv/356012.csv', '../../Datasets/t20i_csv/1168114.csv', '../../Datasets/t20i_csv/1256724.csv', '../../Datasets/t20i_csv/1201668.csv', '../../Datasets/t20i_csv/356006.csv', '../../Datasets/t20i_csv/800479.csv', '../../Datasets/t20i_csv/1310942.csv', '../../Datasets/t20i_csv/1201683.csv', '../../Datasets/t20i_csv/1332507.csv', '../../Datasets/t20i_csv/540173.csv', '../../Datasets/t20i_csv/875541.csv', '../../Datasets/t20i_csv/287878.csv', '../../Datasets/t20i_csv/1299579.csv', '../../Datasets/t20i_csv/1072206.csv', '../../Datasets/t20i_csv/1130747.csv', '../../Datasets/t20i_csv/1348650.csv', '../../Datasets/t20i_csv/546462.csv', '../../Datasets/t20i_csv/1152840.csv', '../../Datasets/t20i_csv/1199502.csv', '../../Datasets/t20i_csv/12752
# ...

# %%
df = pd.concat((pd.read_csv(f, header = 0) for f in allT20i_csvs))

# %%
df
# Out:
#      match_id   season  start_date                    venue  innings  ball  \
# 0     1217744  2019/20  2020-03-04  Terdthai Cricket Ground        1   0.1
# 1     1217744  2019/20  2020-03-04  Terdthai Cricket Ground        1   0.2
# 2     1217744  2019/20  2020-03-04  Terdthai Cricket Ground        1   0.3
# 3     1217744  2019/20  2020-03-04  Terdthai Cricket Ground        1   0.4
# 4     1217744  2019/20  2020-03-04  Terdthai Cricket Ground        1   0.5
# ..        ...      ...         ...                      ...      ...   ...
# 187   1142914     2018  2018-07-02       Harare Sports Club        2  10.1
# 188   1142914     2018  2018-07-02       Harare Sports Club        2  10.2
# 189   1142914     2018  2018-07-02       Harare Sports Club        2  10.3
# 190   1142914     2018  2018-07-02       Harare Sports Club        2  10.4
# 191   1142914     2018  2018-07-02       Harare Sports Club        2  10.5
#
# ...

# %%
print('Total matches: ',len(df.match_id.unique()))
# Out:
# Total matches:  1746

# %%
df.to_csv('../Material/T20Is.csv', index=None)
