# %%
import pandas as pd
import glob

# %%
d1 = pd.read_csv('../../Datasets/odis_csv/64814.csv')
d2 = pd.read_csv('../../Datasets/odis_csv/212452.csv')

# %%
d1.head()
# Out:
#    match_id   season  start_date                venue  innings  ball  \
# 0     64814  2002/03  2002-12-29  McLean Park, Napier        1   0.1
# 1     64814  2002/03  2002-12-29  McLean Park, Napier        1   0.2
# 2     64814  2002/03  2002-12-29  McLean Park, Napier        1   0.3
# 3     64814  2002/03  2002-12-29  McLean Park, Napier        1   0.4
# 4     64814  2002/03  2002-12-29  McLean Park, Napier        1   0.5
#
#   batting_team bowling_team     striker non_striker  ... extras  wides  \
# 0  New Zealand        India  SP Fleming    NJ Astle  ...      1    NaN
# 1  New Zealand        India    NJ Astle  SP Fleming  ...      0    NaN
# 2  New Zealand        India    NJ Astle  SP Fleming  ...      0    NaN
# 3  New Zealand        India    NJ Astle  SP Fleming  ...      0    NaN
# 4  New Zealand        India  SP Fleming    NJ Astle  ...      0    NaN
#
#    noballs  byes  legbyes  penalty  wicket_type  player_dismissed  \
# ...

# %%
d2.head()
# Out:
#    match_id  season  start_date   venue  innings  ball batting_team  \
# 0    212452    2005  2005-07-02  Lord's        1   0.1    Australia
# 1    212452    2005  2005-07-02  Lord's        1   0.2    Australia
# 2    212452    2005  2005-07-02  Lord's        1   0.3    Australia
# 3    212452    2005  2005-07-02  Lord's        1   0.4    Australia
# 4    212452    2005  2005-07-02  Lord's        1   0.5    Australia
#
#   bowling_team       striker   non_striker  ... extras  wides  noballs  byes  \
# 0      England  AC Gilchrist     ML Hayden  ...      0    NaN      NaN   NaN
# 1      England     ML Hayden  AC Gilchrist  ...      0    NaN      NaN   NaN
# 2      England     ML Hayden  AC Gilchrist  ...      0    NaN      NaN   NaN
# 3      England  AC Gilchrist     ML Hayden  ...      0    NaN      NaN   NaN
# 4      England  AC Gilchrist     ML Hayden  ...      4    NaN      NaN   4.0
#
#    legbyes  penalty  wicket_type  player_dismissed other_wicket_type  \
# ...

# %%
d1.columns == d2.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
allODI_csvs = glob.glob('../../Datasets/odis_csv/*.csv')

# %%
print(allODI_csvs)
# Out:
# ['../../Datasets/odis_csv/291217.csv', '../../Datasets/odis_csv/1302349.csv', '../../Datasets/odis_csv/736511.csv', '../../Datasets/odis_csv/560923.csv', '../../Datasets/odis_csv/543888.csv', '../../Datasets/odis_csv/1277098.csv', '../../Datasets/odis_csv/350477.csv', '../../Datasets/odis_csv/1277073.csv', '../../Datasets/odis_csv/64905.csv', '../../Datasets/odis_csv/702139.csv', '../../Datasets/odis_csv/476600.csv', '../../Datasets/odis_csv/64911.csv', '../../Datasets/odis_csv/64939.csv', '../../Datasets/odis_csv/1029821.csv', '../../Datasets/odis_csv/573022.csv', '../../Datasets/odis_csv/571147.csv', '../../Datasets/odis_csv/1077949.csv', '../../Datasets/odis_csv/313994.csv', '../../Datasets/odis_csv/1131277.csv', '../../Datasets/odis_csv/212452.csv', '../../Datasets/odis_csv/247490.csv', '../../Datasets/odis_csv/1144171.csv', '../../Datasets/odis_csv/247484.csv', '../../Datasets/odis_csv/531985.csv', '../../Datasets/odis_csv/464990.csv', '../../Datasets/odis_csv/1144159.csv', '../
# ...

# %%
df = pd.concat((pd.read_csv(f, header = 0) for f in allODI_csvs))

# %%
df
# Out:
#      match_id   season  start_date                                   venue  \
# 0      291217  2007/08  2007-10-01  Rangiri Dambulla International Stadium
# 1      291217  2007/08  2007-10-01  Rangiri Dambulla International Stadium
# 2      291217  2007/08  2007-10-01  Rangiri Dambulla International Stadium
# 3      291217  2007/08  2007-10-01  Rangiri Dambulla International Stadium
# 4      291217  2007/08  2007-10-01  Rangiri Dambulla International Stadium
# ..        ...      ...         ...                                     ...
# 587    710295  2013/14  2014-02-27           Khan Shaheb Osman Ali Stadium
# 588    710295  2013/14  2014-02-27           Khan Shaheb Osman Ali Stadium
# 589    710295  2013/14  2014-02-27           Khan Shaheb Osman Ali Stadium
# 590    710295  2013/14  2014-02-27           Khan Shaheb Osman Ali Stadium
# 591    710295  2013/14  2014-02-27           Khan Shaheb Osman Ali Stadium
#
#      innings  ball batting_team bowling_team             striker  \
# ...

# %%
print('Total matches: ',len(df.match_id.unique()))
# Out:
# Total matches:  2248

# %%
df.to_csv('../Material/ODIs.csv', index=None)
