# %% [markdown]
# # **Modelling the Cricsheet data**

# %%
import pandas as pd
import glob

# %%
d1 = pd.read_csv('Data/1001351.csv')

# %%
d2 = pd.read_csv('Data/1001353.csv')

# %%
d1.head()
# Out:
#    match_id   season  start_date                           venue  innings  \
# 0   1001351  2016/17  2017-02-19  Simonds Stadium, South Geelong        1
# 1   1001351  2016/17  2017-02-19  Simonds Stadium, South Geelong        1
# 2   1001351  2016/17  2017-02-19  Simonds Stadium, South Geelong        1
# 3   1001351  2016/17  2017-02-19  Simonds Stadium, South Geelong        1
# 4   1001351  2016/17  2017-02-19  Simonds Stadium, South Geelong        1
#
#    ball batting_team bowling_team    striker non_striker  ... extras  wides  \
# 0   0.1    Australia    Sri Lanka  M Klinger    AJ Finch  ...      0    NaN
# 1   0.2    Australia    Sri Lanka  M Klinger    AJ Finch  ...      0    NaN
# 2   0.3    Australia    Sri Lanka   AJ Finch   M Klinger  ...      0    NaN
# 3   0.4    Australia    Sri Lanka   AJ Finch   M Klinger  ...      0    NaN
# 4   0.5    Australia    Sri Lanka   AJ Finch   M Klinger  ...      1    NaN
#
# ...

# %%
d2.head()
# Out:
#    match_id   season  start_date          venue  innings  ball batting_team  \
# 0   1001353  2016/17  2017-02-22  Adelaide Oval        1   0.1    Australia
# 1   1001353  2016/17  2017-02-22  Adelaide Oval        1   0.2    Australia
# 2   1001353  2016/17  2017-02-22  Adelaide Oval        1   0.3    Australia
# 3   1001353  2016/17  2017-02-22  Adelaide Oval        1   0.4    Australia
# 4   1001353  2016/17  2017-02-22  Adelaide Oval        1   0.5    Australia
#
#   bowling_team   striker non_striker  ... extras  wides  noballs  byes  \
# 0    Sri Lanka  AJ Finch   M Klinger  ...      0    NaN      NaN   NaN
# 1    Sri Lanka  AJ Finch   M Klinger  ...      0    NaN      NaN   NaN
# 2    Sri Lanka  AJ Finch   M Klinger  ...      0    NaN      NaN   NaN
# 3    Sri Lanka  AJ Finch   M Klinger  ...      0    NaN      NaN   NaN
# 4    Sri Lanka  AJ Finch   M Klinger  ...      0    NaN      NaN   NaN
#
#    legbyes  penalty  wicket_type  player_dismissed other_wicket_type  \
# ...

# %%
d1.columns == d2.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
all_files = glob.glob("./Data/*.csv") 
print(all_files)
# Out:
# ['./Data\\1001349.csv', './Data\\1001351.csv', './Data\\1001353.csv', './Data\\1004729.csv', './Data\\1007655.csv', './Data\\1007657.csv', './Data\\1007659.csv', './Data\\1019979.csv', './Data\\1019981.csv', './Data\\1019983.csv', './Data\\1020029.csv', './Data\\1031431.csv', './Data\\1031433.csv', './Data\\1031435.csv', './Data\\1031665.csv', './Data\\1034825.csv', './Data\\1034827.csv', './Data\\1034829.csv', './Data\\1040485.csv', './Data\\1040487.csv', './Data\\1040489.csv', './Data\\1041615.csv', './Data\\1041617.csv', './Data\\1050217.csv', './Data\\1050219.csv', './Data\\1050221.csv', './Data\\1072206.csv', './Data\\1072207.csv', './Data\\1072208.csv', './Data\\1072316.csv', './Data\\1072317.csv', './Data\\1072318.csv', './Data\\1072319.csv', './Data\\1072320.csv', './Data\\1072321.csv', './Data\\1072322.csv', './Data\\1074957.csv', './Data\\1074958.csv', './Data\\1074959.csv', './Data\\1074961.csv', './Data\\1074962.csv', './Data\\1074964.csv', './Data\\1074965.csv', './Data\
# ...

# %%
df = pd.concat((pd.read_csv(f, header = 0) for f in all_files))

# %%
df
# Out:
#      match_id   season  start_date                     venue  innings  ball  \
# 0     1001349  2016/17  2017-02-17  Melbourne Cricket Ground        1   0.1
# 1     1001349  2016/17  2017-02-17  Melbourne Cricket Ground        1   0.2
# 2     1001349  2016/17  2017-02-17  Melbourne Cricket Ground        1   0.3
# 3     1001349  2016/17  2017-02-17  Melbourne Cricket Ground        1   0.4
# 4     1001349  2016/17  2017-02-17  Melbourne Cricket Ground        1   0.5
# ..        ...      ...         ...                       ...      ...   ...
# 231    995469     2016  2016-09-09       R Premadasa Stadium        2  17.1
# 232    995469     2016  2016-09-09       R Premadasa Stadium        2  17.2
# 233    995469     2016  2016-09-09       R Premadasa Stadium        2  17.3
# 234    995469     2016  2016-09-09       R Premadasa Stadium        2  17.4
# 235    995469     2016  2016-09-09       R Premadasa Stadium        2  17.5
#
# ...

# %%
len(df)
# Out:
# 221733

# %%
len(df.match_id.unique())
# Out:
# 966

# %%
df.to_csv("Data.csv",index=None)
